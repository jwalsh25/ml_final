# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# read in the data
df = pd.read_csv('openpowerlifting.csv')
df.head()
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_44080\2412333633.py:2: DtypeWarning: Columns (33,35,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('openpowerlifting.csv')
#                 Name Sex Event Equipment   Age AgeClass BirthYearClass  \
# 0     E.S. Denisenko   F     B       Raw  28.5    24-34          24-39
# 1    I.S. Lebetskaya   F     B       Raw  43.5    40-44          40-49
# 2      K. Yakimovich   F     B       Raw  26.5    24-34          24-39
# 3       A.G. Golneva   F     B       Raw  19.5    20-23          19-23
# 4  E.V. Marunevskaya   F     B       Raw  19.5    20-23          19-23
#
#         Division  BodyweightKg WeightClassKg  ...  Country  State  \
# 0           Open          67.3           NaN  ...      NaN    NaN
# 1           Open          73.2           NaN  ...      NaN    NaN
# 2           Open          60.6           NaN  ...      NaN    NaN
# 3  Juniors 17-21          50.3           NaN  ...      NaN    NaN
# 4  Juniors 17-21          63.7           NaN  ...      NaN    NaN
#
#     Federation  ParentFederation        Date  MeetCountry  MeetState  \
# 0  GSF-Belarus               NaN  2019-06-22      Belarus        NaN
# 1  GSF-Belarus               NaN  2019-06-22      Belarus        NaN
# 2  GSF-Belarus               NaN  2019-06-22      Belarus        NaN
# 3  GSF-Belarus               NaN  2019-06-22      Belarus        NaN
# 4  GSF-Belarus               NaN  2019-06-22      Belarus        NaN
#
#    MeetTown         MeetName  Sanctioned
# 0  Luninets  Bison Power Cup         Yes
# 1  Luninets  Bison Power Cup         Yes
# 2  Luninets  Bison Power Cup         Yes
# 3  Luninets  Bison Power Cup         Yes
# 4  Luninets  Bison Power Cup         Yes
#
# [5 rows x 42 columns]

# %%
df.shape
# Out:
# (3565052, 42)

# %%
# Selecte only tested full power meets
df = df[df["Event"] == "SBD"]
df = df[df["Tested"] == "Yes"]
df.shape
# Out:
# (2039706, 42)

# %%
df.columns
# Out:
# Index(['Name', 'Sex', 'Event', 'Equipment', 'Age', 'AgeClass',
#        'BirthYearClass', 'Division', 'BodyweightKg', 'WeightClassKg',
#        'Squat1Kg', 'Squat2Kg', 'Squat3Kg', 'Squat4Kg', 'Best3SquatKg',
#        'Bench1Kg', 'Bench2Kg', 'Bench3Kg', 'Bench4Kg', 'Best3BenchKg',
#        'Deadlift1Kg', 'Deadlift2Kg', 'Deadlift3Kg', 'Deadlift4Kg',
#        'Best3DeadliftKg', 'TotalKg', 'Place', 'Dots', 'Wilks', 'Glossbrenner',
#        'Goodlift', 'Tested', 'Country', 'State', 'Federation',
#        'ParentFederation', 'Date', 'MeetCountry', 'MeetState', 'MeetTown',
#        'MeetName', 'Sanctioned'],
#       dtype='object')

# %%
# Drop columns that are not useful
df.drop(["Event", "Squat4Kg", "Bench4Kg", "Deadlift4Kg", "Tested", 
         "MeetName", "Wilks", "Glossbrenner", "Goodlift", "Sanctioned",
         "AgeClass", "BirthYearClass", "Country", "State", "MeetCountry",
         "MeetState", "MeetTown"], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Name', 'Sex', 'Equipment', 'Age', 'Division', 'BodyweightKg',
#        'WeightClassKg', 'Squat1Kg', 'Squat2Kg', 'Squat3Kg', 'Best3SquatKg',
#        'Bench1Kg', 'Bench2Kg', 'Bench3Kg', 'Best3BenchKg', 'Deadlift1Kg',
#        'Deadlift2Kg', 'Deadlift3Kg', 'Best3DeadliftKg', 'TotalKg', 'Place',
#        'Dots', 'Federation', 'ParentFederation', 'Date'],
#       dtype='object')

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#                          Name Sex Equipment   Age Division  BodyweightKg  \
# 0              Darya Grischuk   F     Wraps  13.5       T1         50.40
# 1         Tetyana Shtembulyak   F     Wraps  29.0        O         51.40
# 2          Marianna Dolinnaya   F     Wraps  30.5        O         50.85
# 3  Anastasiya Kalashnikova #1   F     Wraps  32.0        O         53.50
# 4              Alla Ryazanova   F     Wraps  37.0        O         55.80
#
#   WeightClassKg  Squat1Kg  Squat2Kg  Squat3Kg  ...  Deadlift1Kg  Deadlift2Kg  \
# 0            52      65.0      75.0     -80.0  ...         75.0        -80.0
# 1            52      95.0    -105.0     105.0  ...        100.0       -110.0
# 2            52      85.0     -90.0      90.0  ...         80.0         85.0
# 3            56     127.5     135.0     142.5  ...        130.0        140.0
# 4            56     -80.0      90.0    -105.0  ...        120.0        127.5
#
#    Deadlift3Kg  Best3DeadliftKg  TotalKg  Place    Dots  Federation  \
# 0        -80.0             75.0    185.0      1  230.50     WPC-UKR
# 1       -110.0            100.0    255.0      1  313.35     WPC-UKR
# 2        -90.0             85.0    215.0      2  266.20     WPC-UKR
# 3       -147.5            140.0    357.5      1  427.31     WPC-UKR
# 4        140.0            140.0    275.0      2  319.51     WPC-UKR
#
#    ParentFederation        Date
# 0               WPC  2017-10-21
# 1               WPC  2017-10-21
# 2               WPC  2017-10-21
# 3               WPC  2017-10-21
# 4               WPC  2017-10-21
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (2039706, 25)

# %%
# Drop rows for multiple divisions at the same meet
df = df.drop_duplicates(subset=["Name", "Date", "Federation"])
df.shape
# Out:
# (1966297, 25)

# %%
df = df[df["TotalKg"] > 0]

# %%
NUM_MEETS = 10
# Filter for people with more than N meets
lifters = df[df.groupby('Name')['Name'].transform('size') >= NUM_MEETS]
lifters.shape
# Out:
# (550386, 25)

# %%
# Encode fields
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
lifters['Sex'] = le.fit_transform(lifters['Sex'])
lifters['Equipment'] = le.fit_transform(lifters['Equipment'])
lifters['Division'] = le.fit_transform(lifters['Division'])
lifters['Federation'] = le.fit_transform(lifters['Federation'])
lifters['ParentFederation'] = le.fit_transform(lifters['ParentFederation'])
lifters['Place'] = le.fit_transform(lifters['Place'])
lifters['WeightClassKg'] = le.fit_transform(lifters['WeightClassKg'])
lifters['Date'] = pd.to_datetime(lifters['Date'])
lifters.head()
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\3870858600.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters['Sex'] = le.fit_transform(lifters['Sex'])
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\3870858600.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters['Equipment'] = le.fit_transform(lifters['Equipment'])
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\3870858600.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters['Division'] = le.fit_transform(lifters['Division'])
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\3870858600.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters['Federation'] = le.fit_transform(lifters['Federation'])
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\3870858600.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters['ParentFederation'] = le.fit_transform(lifters['ParentFederation'])
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\3870858600.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters['Place'] = le.fit_transform(lifters['Place'])
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\3870858600.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters['WeightClassKg'] = le.fit_transform(lifters['WeightClassKg'])
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\3870858600.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters['Date'] = pd.to_datetime(lifters['Date'])
#                      Name  Sex  Equipment   Age  Division  BodyweightKg  \
# 26     Volodymyr Ogloblin    1          4  51.5      1088         106.0
# 54   Anatoliy Bochkovskyy    1          4  58.5       680          67.0
# 73       Eduard Dolgov #1    1          4  25.0      1088          82.1
# 80         Stepan Sagirov    1          4  20.0       444          88.7
# 101    Volodymyr Ogloblin    1          4  47.5       676         100.0
#
#      WeightClassKg  Squat1Kg  Squat2Kg  Squat3Kg  ...  Deadlift1Kg  \
# 26              14     220.0     230.0     240.0  ...        275.0
# 54              98     147.5     167.5       NaN  ...        187.5
# 73             126     240.0     250.0       NaN  ...        260.0
# 80             146     200.0     210.0     220.0  ...        215.0
# 101              1     210.0     220.0    -230.0  ...        240.0
#
#      Deadlift2Kg  Deadlift3Kg  Best3DeadliftKg  TotalKg  Place    Dots  \
# 26        -282.5        282.5            282.5    647.5      0  389.03
# 54         207.5          NaN            207.5    462.5      0  358.40
# 73        -270.0       -270.0            260.0    690.0      0  468.69
# 80         225.0        235.0            235.0    610.0      0  397.36
# 101        250.0        255.0            255.0    605.0      0  372.39
#
#      Federation  ParentFederation       Date
# 26          174                10 2017-10-21
# 54          174                10 2013-04-06
# 73          174                10 2013-04-06
# 80          174                10 2013-04-06
# 101         174                10 2013-04-06
#
# [5 rows x 25 columns]

# %%
lifters["MinDate"] = lifters.groupby("Name")["Date"].transform("min")
lifters["Time"] = (lifters["Date"] - lifters["MinDate"]).dt.days
lifters.drop(["Date", "MinDate"], axis=1, inplace=True)
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\2933492349.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["MinDate"] = lifters.groupby("Name")["Date"].transform("min")
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\2933492349.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["Time"] = (lifters["Date"] - lifters["MinDate"]).dt.days
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\2933492349.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters.drop(["Date", "MinDate"], axis=1, inplace=True)

# %%
lifters["Squat1Kg"].fillna(0, inplace=True)
lifters["Bench1Kg"].fillna(0, inplace=True)
lifters["Deadlift1Kg"].fillna(0, inplace=True)
lifters["Squat2Kg"].fillna(0, inplace=True)
lifters["Bench2Kg"].fillna(0, inplace=True)
lifters["Deadlift2Kg"].fillna(0, inplace=True)
lifters["Squat3Kg"].fillna(0, inplace=True)
lifters["Bench3Kg"].fillna(0, inplace=True)
lifters["Deadlift3Kg"].fillna(0, inplace=True)
lifters["Best3SquatKg"].fillna(0, inplace=True)
lifters["Best3BenchKg"].fillna(0, inplace=True)
lifters["Best3DeadliftKg"].fillna(0, inplace=True)
lifters["TotalKg"].fillna(0, inplace=True)

lifters["Place"].fillna(-1, inplace=True)
lifters["Age"].fillna(-1, inplace=True)
lifters["BodyweightKg"].fillna(-1, inplace=True)
lifters["Dots"].fillna(0, inplace=True)
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["Squat1Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["Squat1Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["Bench1Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["Bench1Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["Deadlift1Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["Deadlift1Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["Squat2Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["Squat2Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["Bench2Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["Bench2Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["Deadlift2Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["Deadlift2Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["Squat3Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["Squat3Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["Bench3Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["Bench3Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["Deadlift3Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["Deadlift3Kg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["Best3SquatKg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["Best3SquatKg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["Best3BenchKg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["Best3BenchKg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["Best3DeadliftKg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["Best3DeadliftKg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["TotalKg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["TotalKg"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["Place"].fillna(-1, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["Place"].fillna(-1, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["Age"].fillna(-1, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["Age"].fillna(-1, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["BodyweightKg"].fillna(-1, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["BodyweightKg"].fillna(-1, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lifters["Dots"].fillna(0, inplace=True)
# C:\Users\charl\AppData\Local\Temp\ipykernel_1944\1690070775.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lifters["Dots"].fillna(0, inplace=True)

# %%
lifters.isna().any()
# Out:
# Name                False
# Sex                 False
# Equipment           False
# Age                 False
# Division            False
# BodyweightKg        False
# WeightClassKg       False
# Squat1Kg            False
# Squat2Kg            False
# Squat3Kg            False
# Best3SquatKg        False
# Bench1Kg            False
# Bench2Kg            False
# Bench3Kg            False
# Best3BenchKg        False
# Deadlift1Kg         False
# Deadlift2Kg         False
# Deadlift3Kg         False
# Best3DeadliftKg     False
# TotalKg             False
# Place               False
# Dots                False
# Federation          False
# ParentFederation    False
# Time                False
# dtype: bool

# %%
def plot_lifter(name):
    lifters[lifters["Name"] == name].sort_values("Time")
    x = lifters[lifters["Name"] == name].sort_values("Time")["Time"].to_numpy()
    y = lifters[lifters["Name"] == name].sort_values("Time")["TotalKg"].to_numpy()
    plt.plot(x, y)
    plt.xlabel("Time (days)")
    plt.ylabel("Total (kg)")
    plt.title(name)
    plt.show()

# %%
plot_lifter("Austin Perkins #1")

# %%
ap = lifters[lifters["Name"] == "Austin Perkins #1"]
recent = ap.sort_values("Time").tail(NUM_MEETS)
recent
# Out:
#                       Name  Sex  Equipment   Age  Division  BodyweightKg  \
# 310515   Austin Perkins #1    1          1  21.5       754         73.44
# 328892   Austin Perkins #1    1          1  21.5       731         73.15
# 307234   Austin Perkins #1    1          1  22.5       754         72.50
# 247744   Austin Perkins #1    1          1  23.0       731         72.95
# 410086   Austin Perkins #1    1          1  23.5       754         73.90
# 339604   Austin Perkins #1    1          1  23.5       754         74.24
# 1888022  Austin Perkins #1    1          1  24.0       754         75.00
# 1886120  Austin Perkins #1    1          1  24.0       754         73.25
# 11533    Austin Perkins #1    1          1  24.5      1090         72.75
# 27685    Austin Perkins #1    1          1  25.0      1090         73.90
#
#          WeightClassKg  Squat1Kg  Squat2Kg  Squat3Kg  ...  Deadlift1Kg  \
# 310515             108     275.0     290.0    -295.0  ...        285.0
# 328892             159     267.5     282.5     292.5  ...        282.5
# 307234             111     270.0     282.5     292.5  ...        280.0
# 247744             111     275.0     287.5    -300.0  ...        280.0
# 410086             111     280.0     295.0     305.0  ...        285.0
# 339604             111     287.5     303.5     313.5  ...        302.5
# 1888022            128      25.0       0.0       0.0  ...         75.0
# 1886120            108     292.5     308.0     318.0  ...        307.5
# 11533              108     290.0     305.5     311.0  ...        300.0
# 27685              159     300.0     315.0     323.0  ...        305.0
#
#          Deadlift2Kg  Deadlift3Kg  Best3DeadliftKg  TotalKg  Place    Dots  \
# 310515         295.0        300.0            300.0    770.0     13  559.98
# 328892         300.0        312.5            312.5    780.0      0  568.73
# 307234         297.5        317.5            317.5    790.0      0  579.43
# 247744         300.0       -325.0            300.0    775.0      0  566.10
# 410086         305.0        325.0            325.0    825.0      0  597.54
# 339604         327.5        337.5            337.5    851.0      0  614.54
# 1888022          0.0          0.0             75.0    125.0     24   89.68
# 1886120        326.0          0.0            326.0    839.0      0  611.20
# 11533          317.5        325.0            325.0    836.0      0  611.77
# 27685          320.0       -332.5            320.0    843.0     46  610.57
#
#          Federation  ParentFederation  Time
# 310515          149                 4  1913
# 328892          149                16  2086
# 307234          149                16  2331
# 247744          149                16  2457
# 410086          149                16  2618
# 339604          149                16  2735
# 1888022           7                 4  2822
# 1886120           7                 4  2917
# 11533            74                 4  3010
# 27685            74                 4  3235
#
# [10 rows x 25 columns]

# %%
X = []
y = []
DEBUG = False

names = lifters["Name"].unique()
print(len(names))
for i in tqdm(range(len(names))):
    if DEBUG and i == 100:
        break
    name = names[i]
    lifter = lifters[lifters["Name"] == name]
    lifter_sorted = lifter.sort_values("Time")
    history = lifter_sorted[-NUM_MEETS: -1].copy()
    history.drop("Name", axis=1, inplace=True)
    history = history.to_numpy().flatten()
    time_to_recent = lifter_sorted[-1:]["Time"].to_numpy() - lifter_sorted[-2:-1]["Time"].to_numpy()
    equipment = lifter_sorted[-1:]["Equipment"].to_numpy()
    test = pd.DataFrame(history)
    if test.isnull().values.any():
        print("NaN history")
        print(time_to_recent)
        print(equipment)
        print(history)
        print(i)
        break
    # Check if null
    if np.isnan(time_to_recent):
        print("NaN time_to_recent")
        print(time_to_recent)
        print(equipment)
        print(history)
        print(i)
        break
    # Check if null
    if np.isnan(equipment):
        print("NaN equipment")
        print(time_to_recent)
        print(equipment)
        print(history)
        print(i)
        break
    history = np.append(history, time_to_recent)
    history = np.append(history, equipment)
    recent = lifter_sorted[-1:]
    X.append(history)
    y.append(recent["TotalKg"].to_numpy())
# Out:
# 35405
# 100%|██████████| 35405/35405 [37:47<00:00, 15.62it/s]

# %%
testing = pd.DataFrame(X)

# %%
testing.isna().any(axis=0)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 213    False
# 214    False
# 215    False
# 216    False
# 217    False
# Length: 218, dtype: bool

# %%
testing.loc[testing.isna().any(axis=1),testing.isna().any(axis=0)]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
X = pd.DataFrame(X)
y = pd.DataFrame(y)
X.to_csv(f"X_{NUM_MEETS}_no_bombs.csv", index=False)
y.to_csv(f"y_{NUM_MEETS}_no_bombs.csv", index=False)
